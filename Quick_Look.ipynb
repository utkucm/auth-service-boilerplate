# %% [markdown]
# <a href="https://colab.research.google.com/github/utkucm/auth-service-boilerplate/blob/main/Quick_Look.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Importing packages

# %%
import numpy as np
import pandas as pd
import statsmodels.api as sm
import statsmodels.formula.api as smf

# %% [markdown]
# Loading dataset

# %%
data = sm.datasets.get_rdataset("Guerry", "HistData").data

# %% [markdown]
# Taking a look at data

# %%
data
# Out:
#     dept Region    Department  Crime_pers  Crime_prop  Literacy  Donations  \
# 0      1      E           Ain       28870       15890        37       5098
# 1      2      N         Aisne       26226        5521        51       8901
# 2      3      C        Allier       26747        7925        13      10973
# 3      4      E  Basses-Alpes       12935        7289        46       2733
# 4      5      E  Hautes-Alpes       17488        8174        69       6962
# ..   ...    ...           ...         ...         ...       ...        ...
# 81    86      W        Vienne       15010        4710        25       8922
# 82    87      C  Haute-Vienne       16256        6402        13      13817
# 83    88      E        Vosges       18835        9044        62       4040
# 84    89      C         Yonne       18006        6516        47       4276
# 85   200    NaN         Corse        2199        4589        49      37015
#
#     Infants  Suicides MainCity  ...  Crime_parents  Infanticide  \
# ...

# %% [markdown]
# Fitting OLS regression

# %%
res = smf.ols("Lottery ~ Literacy + np.log(Pop1831)", data=data).fit()

# %%
print(res.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                Lottery   R-squared:                       0.348
# Model:                            OLS   Adj. R-squared:                  0.333
# Method:                 Least Squares   F-statistic:                     22.20
# Date:                Wed, 13 Jul 2022   Prob (F-statistic):           1.90e-08
# Time:                        12:54:32   Log-Likelihood:                -379.82
# No. Observations:                  86   AIC:                             765.6
# Df Residuals:                      83   BIC:                             773.0
# Df Model:                           2
# Covariance Type:            nonrobust
# ...
#                       coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------
# Intercept         246.4341     35.233      6.995      0.000     176.358     316.510
# ...
